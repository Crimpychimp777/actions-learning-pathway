# %% [markdown]
# <a href="https://colab.research.google.com/github/Crimpychimp777/actions-learning-pathway/blob/SUU-Data-Analytics-1-6100/correlation_matrix_in_time_series_data_Participation_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A correlation matrix in time series data analysis serves several important purposes. It helps in understanding the relationships between different time series or between a time series and its lagged versions. This assignment evaluates students' understanding about lagged time series and use of python code to compute correlation matrix of original series with lagged series.
#
# Computing a lagged correlation matrix manually involves calculating the correlation coefficients between a time series and its lagged versions. Here are the steps to compute a lagged correlation matrix for a given time series:
#
#     Create lagged series: Generate lagged versions of the time series for the desired lags. For example, if you want to compute correlations up to lag , you will create lagged series  where represents the series lagged by periods.
#     Align Series: Ensure the lagged series are aligned properly. For lag , ​ will have missing values for the first observations.
#     Compute Correlations: Calculate the correlation between the original time series and each of the lagged series.

# %%
import pandas as pd

#given time series data
data = [23.2, 23.6, 25.3,25.2,25.1,25.6,24.6]
ts = pd.Series(data)
print("Lagged Table:")
print(df)
# create lagged series up to lag 4
df = pd.DataFrame({'Original': ts})
for lag in range(1,5):
  df[f'Lag_{lag}'] = ts.shift(lag)

# compute the correlation matrix, dropping rows with NaN values
corr_matrix = df.corr()
print(corr_matrix)
# Out:
# Lagged Table:
#    Original  Lag_1  Lag_2  Lag_3  Lag_4
# 0      23.2    NaN    NaN    NaN    NaN
# 1      23.6   23.2    NaN    NaN    NaN
# 2      25.3   23.6   23.2    NaN    NaN
# 3      25.2   25.3   23.6   23.2    NaN
# 4      25.1   25.2   25.3   23.6   23.2
# 5      25.6   25.1   25.2   25.3   23.6
# 6      24.6   25.6   25.1   25.2   25.3
#           Original     Lag_1     Lag_2     Lag_3     Lag_4
# Original  1.000000  0.501447 -0.201843 -0.046845 -0.762299
# Lag_1     0.501447  1.000000  0.683067  0.199786  0.932159
# Lag_2    -0.201843  0.683067  1.000000  0.628701 -0.941663
# Lag_3    -0.046845  0.199786  0.628701  1.000000  0.606381
# Lag_4    -0.762299  0.932159 -0.941663  0.606381  1.000000
