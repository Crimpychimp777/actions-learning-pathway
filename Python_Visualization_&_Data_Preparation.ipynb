# %% [markdown]
# <a href="https://colab.research.google.com/github/Crimpychimp777/actions-learning-pathway/blob/main/Python_Visualization_%26_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# command to tell python to actually display the graphs
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
analytics = pd.read_csv('/content/drive/MyDrive/SUU Data Analytics/Module 2/Automobile -1.csv')
#df = pd.read_csv('/location on your computer/automobile (1).csv)

# %%
analytics.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
analytics.shape
# Out:
# (201, 26)

# %%
df=analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.describe(include='all').T
# Out:
#                      count unique     top freq          mean          std  \
# symboling            201.0    NaN     NaN  NaN      0.840796     1.254802
# normalized_losses    201.0    NaN     NaN  NaN    125.189055    33.572966
# make                   201     22  toyota   32           NaN          NaN
# fuel_type              201      2     gas  181           NaN          NaN
# aspiration             201      2     std  165           NaN          NaN
# number_of_doors        201      2    four  114           NaN          NaN
# body_style             201      5   sedan   94           NaN          NaN
# drive_wheels           201      3     fwd  118           NaN          NaN
# engine_location        201      2   front  198           NaN          NaN
# wheel_base           201.0    NaN     NaN  NaN     98.797015     6.066366
# length               201.0    NaN     NaN  NaN    174.200995    12.322175
# width                201.0    NaN     NaN  NaN     65.889055     2.101471
# ...

# %%
import os

# List all files and directories in your Google Drive's MyDrive
# This command recursively lists contents of /content/drive/MyDrive
# !ls -R /content/drive/MyDrive
# Out:
# /content/drive/MyDrive:
# 'Colab Notebooks'  'SUU Adv Accounting Data Analytics'	'Tax Return #2.xlsx'
# 'Document Scans'   'SUU Data Analytics'
#
# '/content/drive/MyDrive/Colab Notebooks':
# 'Hands_on_Notebook_NumPy_v1 (1).ipynb'	 Untitled0.ipynb
# 'module 1 load'				 Untitled1.ipynb
#
# '/content/drive/MyDrive/Document Scans':
#  104b5871-e1b3-458c-a2ff-e82a0668c5dd.jpg
#  28d06760-d3d5-4670-8979-6ab4d888d97c.jpg
#  2938b9a7-2900-4d26-b0c8-102bd49fa2c7.jpg
#  2e0bf96a-8540-4ae7-8990-715985d8b758.jpg
#  524d0337-3b6c-48e8-8ffd-b4443b4745f1.jpg
#  58dc78ba-41e0-49e5-8372-dcc6ca5c71fd.jpg
#  63ee73be-7cda-42a9-b082-9f764d707d38.jpg
#  68093418-e5cd-43ab-8b64-6cdfcf5f0294.jpg
#  792e56f1-37ed-4427-9452-de70a63e55d4.jpg
#  9583c534-25c9-4639-a8e4-bc5f38881910.jpg
#  b4ad1401-f0a2-4762-923b-894aa87d2016.jpg
#  c2b8cad1-bf08-46b3-8611-89ea0c2e5a88.jpg
#  cbedef25-4d05-491f-ba44-c2878bcbc030.jpg
#  cca71e74-274b-49c1-b9f6-93285aefbf0a.jpg
#  dc70bee7-2cbb-49e8-bd35-af5f6067dc9e.jpg
# ...
